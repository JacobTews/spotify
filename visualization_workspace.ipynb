# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\00986562\Anaconda3\envs\spotify\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
artist_df = pd.read_feather('cleaned_data/cleaned_artist.feather')
album_df = pd.read_feather('cleaned_data/cleaned_album.feather')
track_df = pd.read_feather('cleaned_data/cleaned_track.feather')
track_feature_df = pd.read_feather('cleaned_data/cleaned_track_features.feather')

# %% [markdown]
# # Explore

# %%
print(artist_df.shape)
print(album_df.shape)
print(track_df.shape)
print(track_feature_df.shape)
# Out:
# (20, 9)
# (459, 9)
# (5058, 9)
# (5057, 11)

# %%
complete_track_df = track_df.merge(track_feature_df, how='outer', on='track_id')
complete_track_df
# Out:
#                     track_id  \
# 0     6DUqgJGRai5W7vgSxwSmRk
# 1     2RV5ZQOformmqqslmPN4G9
# 2     6BlCXoqaXBilMA62hLBCtT
# 3     6gnH9b4GiS7fSXaaY94gG8
# 4     5sjFGklnKyQmEBN9WEMXkm
# ...                      ...
# 5053  0Qwt99sGnAMJ8RlTqFdrLW
# 5054  1h2OlORCn9DcTN6hyaojNd
# 5055  1SneXZBLDralTKJYpspzLc
# 5056  5mrGO9IpAvGmqCjIUB0jcV
# 5057  38GOszCvj4vdjiGuf3WdwV
#
#                                               song_name  \
# 0                Poème for Violin and Orchestra, Op. 25
# 1     Violin Concerto No. 1 in D Major, Op. 19: I. A...
# 2     Violin Concerto No. 1 in D Major, Op. 19: II. ...
# 3     Violin Concerto No. 1 in D Major, Op. 19: III....
# 4     Deux Sérénades (Written for Hilary Hahn): No. ...
# ...                                                 ...
# 5053  Embrace the Wind!: No. 8. Whirligig of the Rel...
# 5054      Embrace the Wind!: Interlude 7: Chilling Wind
# 5055  Embrace the Wind!: No. 9. Mobile Turning in th...
# 5056                                    The End of Love
# 5057                                      22(OVER S∞∞N)
#
#                                            external_url  duration_ms  \
# 0     https://open.spotify.com/track/6DUqgJGRai5W7vg...      1023040
# 1     https://open.spotify.com/track/2RV5ZQOformmqqs...       576480
# 2     https://open.spotify.com/track/6BlCXoqaXBilMA6...       234720
# 3     https://open.spotify.com/track/6gnH9b4GiS7fSXa...       483600
# 4     https://open.spotify.com/track/5sjFGklnKyQmEBN...       470400
# ...                                                 ...          ...
# 5053  https://open.spotify.com/track/0Qwt99sGnAMJ8Rl...       266760
# 5054  https://open.spotify.com/track/1h2OlORCn9DcTN6...       150000
# 5055  https://open.spotify.com/track/1SneXZBLDralTKJ...       714000
# 5056  https://open.spotify.com/track/5mrGO9IpAvGmqCj...       269916
# 5057  https://open.spotify.com/track/38GOszCvj4vdjiG...       146359
#
#       explicit  disc_number type_x                            song_uri_x  \
# 0        False            1  track  spotify:track:6DUqgJGRai5W7vgSxwSmRk
# 1        False            1  track  spotify:track:2RV5ZQOformmqqslmPN4G9
# 2        False            1  track  spotify:track:6BlCXoqaXBilMA62hLBCtT
# 3        False            1  track  spotify:track:6gnH9b4GiS7fSXaaY94gG8
# 4        False            1  track  spotify:track:5sjFGklnKyQmEBN9WEMXkm
# ...        ...          ...    ...                                   ...
# 5053     False            1  track  spotify:track:0Qwt99sGnAMJ8RlTqFdrLW
# 5054     False            1  track  spotify:track:1h2OlORCn9DcTN6hyaojNd
# 5055     False            1  track  spotify:track:1SneXZBLDralTKJYpspzLc
# 5056     False            1  track  spotify:track:5mrGO9IpAvGmqCjIUB0jcV
# 5057     False            1  track  spotify:track:38GOszCvj4vdjiGuf3WdwV
#
#                     album_id  danceability  energy  instrumentalness  \
# 0     2NjZtmTa1FRYlc629X8ueC         0.121  0.1240          0.560000
# 1     2NjZtmTa1FRYlc629X8ueC         0.294  0.1440          0.188000
# 2     2NjZtmTa1FRYlc629X8ueC         0.472  0.2700          0.789000
# 3     2NjZtmTa1FRYlc629X8ueC         0.237  0.1210          0.256000
# 4     2NjZtmTa1FRYlc629X8ueC         0.109  0.0788          0.732000
# ...                      ...           ...     ...               ...
# 5053  2qy5MbzMF34NyUMWJ4ghAn         0.606  0.1250          0.451000
# 5054  2qy5MbzMF34NyUMWJ4ghAn         0.357  0.0617          0.012000
# 5055  2qy5MbzMF34NyUMWJ4ghAn         0.342  0.1500          0.773000
# 5056  3unmbt2xfH7QW1ns53O9Nz         0.275  0.0686          0.000308
# 5057  3RzPenSm6eejRdSIwHef12         0.284  0.2100          0.000009
#
#       liveness  loudness  speechiness    tempo          type_y  valence  \
# 0       0.1070   -22.930       0.0418   91.838  audio_features   0.0352
# 1       0.3840   -25.954       0.0482  106.247  audio_features   0.0809
# 2       0.0552   -23.245       0.0920  150.013  audio_features   0.4670
# 3       0.2710   -22.860       0.0386  103.345  audio_features   0.0710
# 4       0.1080   -25.191       0.0460   91.888  audio_features   0.0360
# ...        ...       ...          ...      ...             ...      ...
# 5053    0.0636    -9.438       0.0753  103.352  audio_features   0.4400
# 5054    0.1670   -15.822       0.0585   75.210  audio_features   0.1310
# 5055    0.1240   -10.314       0.0312   94.028  audio_features   0.1510
# 5056    0.1900   -16.489       0.0345  130.117  audio_features   0.0669
# 5057    0.1010   -10.451       0.0331   73.551  audio_features   0.0493
#
#                                 song_uri_y
# 0     spotify:track:6DUqgJGRai5W7vgSxwSmRk
# 1     spotify:track:2RV5ZQOformmqqslmPN4G9
# 2     spotify:track:6BlCXoqaXBilMA62hLBCtT
# 3     spotify:track:6gnH9b4GiS7fSXaaY94gG8
# 4     spotify:track:5sjFGklnKyQmEBN9WEMXkm
# ...                                    ...
# 5053  spotify:track:0Qwt99sGnAMJ8RlTqFdrLW
# 5054  spotify:track:1h2OlORCn9DcTN6hyaojNd
# 5055  spotify:track:1SneXZBLDralTKJYpspzLc
# 5056  spotify:track:5mrGO9IpAvGmqCjIUB0jcV
# 5057  spotify:track:38GOszCvj4vdjiGuf3WdwV
#
# [5058 rows x 19 columns]

# %%
complete_album_df = complete_track_df.merge(album_df, how='outer', on='album_id')
print(complete_album_df.shape)
# complete_album_df.head(10)
# Out:
# (5059, 27)

# %%
df = complete_album_df.merge(artist_df, how='outer', on='artist_id')
df.shape
# Out:
# C:\Users\00986562\AppData\Local\Temp\ipykernel_34768\100949707.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'type_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df = complete_album_df.merge(artist_df, how='outer', on='artist_id')
# (5059, 35)

# %%
df.columns
# Out:
# Index(['track_id', 'song_name', 'external_url_x', 'duration_ms', 'explicit',
#        'disc_number', 'type_x', 'song_uri_x', 'album_id', 'danceability',
#        'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness',
#        'tempo', 'type_y', 'valence', 'song_uri_y', 'album_name',
#        'external_url_y', 'image_url_x', 'release_date', 'total_tracks',
#        'type_x', 'album_uri', 'artist_id', 'artist_name', 'external url',
#        'genre', 'image_url_y', 'followers', 'popularity', 'type_y',
#        'artist_uri'],
#       dtype='object')

# %%
useful_cols = ['artist_name', 'genre', 'followers', 'popularity',
               'album_name', 'release_date', 'total_tracks',
               'song_name', 'duration_ms', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'valence',
               'artist_id', 'album_id', 'track_id']

# %%
df = df[useful_cols]
